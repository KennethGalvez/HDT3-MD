# %% [markdown]
# Identifica el tipo de archivo .data y la forma de leerlo

# %%
import pandas as pd
data = pd.read_csv('wine_fraud.csv', header=0)

# %% [markdown]
# Estudia las variables cuantitativas mediante técnicas de estadística descriptiva.

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('wine_fraud.csv', header=0)

numeric_data = data.select_dtypes(include='number')
numeric_data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.215307          0.339666     0.318633        5.443235
# std         1.296434          0.164636     0.145318        4.757804
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6497.000000          6497.000000           6497.000000  6497.000000
# mean      0.056034            30.525319            115.744574     0.994697
# std       0.035034            17.749400             56.521855     0.002999
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('wine_fraud.csv')
numeric_data = data.select_dtypes(include='number')

# Crear una figura y subplots
fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(10, 10))

# Gráfico Histogramas
numeric_data.hist(ax=axs[0, 1])
axs[0, 1].set_title('Histogramas')

# Ajustar los subplots para que no se superpongan
plt.tight_layout()

# Mostrar la figura
plt.show()
# Out:
# C:\Users\kenic\AppData\Local\Temp\ipykernel_10044\1955291601.py:11: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   numeric_data.hist(ax=axs[0, 1])

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('wine_fraud.csv')
numeric_data = data.select_dtypes(include='number')

#Diagramas de caja y bigotes
fig, axs = plt.subplots(figsize=(10, 6))
numeric_data.plot.box(ax=axs)
axs.set_title('Diagramas de caja y bigotes')
axs.set_xlabel('Variables')
axs.set_ylabel('Valor')
axs.set_xticklabels(axs.get_xticklabels(), rotation=45, ha='right')

# Mostrar las gráficas
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('wine_fraud.csv')
numeric_data = data[['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides']] # seleccionar solo las columnas de interés

# Gráfico de dispersión
fig, axs = plt.subplots(figsize=(10, 10))
pd.plotting.scatter_matrix(numeric_data, diagonal='hist', ax=axs)
axs.set_title('Gráfico de dispersión')
axs.set_xlabel('Variables')
axs.set_ylabel('Valor')

# Mostrar las gráficas
plt.show()
# Out:
# C:\Users\kenic\AppData\Local\Temp\ipykernel_3348\634244278.py:9: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   pd.plotting.scatter_matrix(numeric_data, diagonal='hist', ax=axs)
